# %%
def func1():
    print("python")

func1()
# Out:
# python

# %%
def func2(n1,n2):
    ret = n1<n2
    return ret

ans = func2(10,5)
print(ans)
# Out:
# False

# %%
for a  in range(1,21):
    if a%3==0:
        print(a, end= ' ')
# Out:
# 3 6 9 12 15 18

# %%
for a  in range(3,21,3):
    print(a, end=' ')
# Out:
# 3 6 9 12 15 18

# %%
sum =0
for a  in range(1,101):
    if a%2==0:
        sum =sum+a
print(sum)
# Out:
# 2550

# %%
sum=0
a=2
while a<=100:
    sum=sum+a
    a+=2
print(sum)count =0
for in inx:
if i ==y:
    count =count +1
return count
# Out:
# 2550

# %%
def cntFunc(x, y):
    count = 0
    for i in x:
        if i == y :
            count = count + 1
    return count


str = "I am a student"
ch = "a"
num = cntFunc(str,ch)
print(f'{num} 개')
# Out:
# 2 개

# %%
a = 10
a = a+5
print(a)
# Out:
# 15

# %%
n = 10//4
print(n != 1)
# Out:
# True

# %%
x = 24%5
y = 2**3
print(x>5 and y<10)
print(x)
# Out:
# False
# 4

# %%
num = int(5.8)
if num%2==0:
    print(f'{num}는 짝수')
else:
    print(f'{num}는 홀수')
# Out:
# 5는 홀수

# %%
a = input('처번쨰 정수 입력: ')
b = input('두번째 정수 입력L ')
c = a+b
print(c)
# Out:
# 처번쨰 정수 입력:  20
# 두번째 정수 입력L  23
# 2023

# %%
for x  in range(3):
    print(x,"봄")
# Out:
# 0 봄
# 1 봄
# 2 봄

# %%
hap = 0
for x in range(2,8,2):
    hap = hap + x
print(hap)
# Out:
# 12

# %%
hap = 0
i = 0
while i <5:
    hap = hap +i
    i = i +1
print(hap)
# Out:
# 10

# %%
def func1():
    print("python")

func1()
# Out:
# python

# %%
def func2(
