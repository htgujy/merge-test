# %% [markdown]
# 코드 3-16

# %%
import random

a = random.randint(1,100)
b = random.randint(1,100)
answer = int(input(f'{a}+{b}= '))
if answer==a+b:
  print('맞혔습니다.')
else:
  print('틀렸습니다.')

a = random.randint(1,100)
b = random.randint(1,100)
answer = int(input(f'{a}+{b}= '))
if answer==a+b:
  print('맞혔습니다.')
else:
  print('틀렸습니다.')

# %% [markdown]
# 코드 3-17

# %%
# import random

def rand_add():
  a = random.randint(1,100)
  b = random.randint(1,100)
  answer = int(input(f'{a}+{b}= '))
  if answer==a+b:
    print('맞혔습니다.')
  else:
    print('틀렸습니다.')

rand_add()
rand_add()

# %% [markdown]
# 코드 3-18

# %%
def func():
  print('함수입니다.')

print('함수 호출 전입니다.')
func()
print('함수 호출 후입니다.')
# Out:
# 함수 호출 전입니다.
# 함수입니다.
# 함수 호출 후입니다.

# %% [markdown]
# 코드 3-19

# %%
def add(x, y):
  print(x+y)

a = int(input('정수: '))
b = int(input('정수: '))
add(a, b)
# Out:
# 정수:  3
# 정수:  5
# 8

# %% [markdown]
# 코드 3-20

# %%
def add(x, y):
  return x+y

a = int(input('정수: '))
b = int(input('정수: '))
c= add(a, b)
print(c)
# Out:
# 정수:  3
# 정수:  5
# 8

# %% [markdown]
# 코드 3-21

# %%
import random

def bigsmall(x, y):
  if x>y:
    return x, y
  else:
    return y, x

a = random.randint(1, 100)
b = random.randint(1, 100)
a, b = bigsmall(a, b)
print(a, b)
# Out:
# 100 62
