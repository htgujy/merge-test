# %% [markdown]
# 코드 2-16

# %%
name = input('이름: ')
age = input('나이: ')
print(name, '나이:', age)

# %% [markdown]
# 코드 2-17

# %%
a = input('정수: ')
b = input('정수: ')
print(a-b)

# %% [markdown]
# 코드 2-18

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(a-b)

# %% [markdown]
# 코드 2-19

# %%
minute = float(input('분 단위 시간: '))
second = minute * 60
print(second, '초')

# %% [markdown]
# 코드 2-20

# %%
print('반갑습니다.')
score = 99
print('성적은', score, '입니다.')

# %% [markdown]
# 코드 2-21

# %%
a = 25
b = 42
print(a)
print(b)

# %% [markdown]
# 코드 2-22

# %%
a = 25
b = 42
print(a, end=' ')
print(b)

# %% [markdown]
# 코드 2-23

# %%
print('안녕!')
print()
print('파이썬')

# %% [markdown]
# 코드 2-24

# %%
name = '홍길동'
age = 20
print('이름은 ', name, '이고 나이는 ', age, '입니다.')

# %% [markdown]
# 코드 2-25

# %%
name = '홍길동'
age = 20
print(f'이름은 {name}이고 나이는 {age}입니다.')
