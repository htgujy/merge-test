# %% [markdown]
# 코드 2-9

# %%
print(type(2024))
print(type(3.14))
print(type('Python'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# 코드 2-10

# %%
a = 20
b = 0o34
c = 0xA1
d = 0b1110
print(a, b, c, d)
# Out:
# 20 28 161 14

# %% [markdown]
# 코드 2-11

# %%
a = 3.14
b = 1.23e5
print(a, b)
# Out:
# 3.14 123000.0

# %% [markdown]
# 코드 2-12

# %%
a = 10>20
print(a)

# %% [markdown]
# 코드 2-13

# %%
a = 'Python'
print(a)

# %% [markdown]
# 코드 2-14

# %%
print('Hi! ' + 'Python')
# Out:
# Hi! Python
