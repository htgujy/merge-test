# %% [markdown]
# 코드 2-1

# %%
age = 20
print(age)
# Out:
# 20

# %% [markdown]
# 코드 2-2

# %%
age = 20
print('age')
# Out:
# age

# %% [markdown]
# 코드 2-3

# %%
age = 20
print(age)
age = 21
print(age)
# Out:
# 20
# 21

# %% [markdown]
# 코드 2-4

# %%
name = '홍길동'
age = 18
print(name, '나이:', age)
# Out:
# 홍길동 나이: 18

# %% [markdown]
# 코드 2-5

# %%
a = 100
a += 10
print(a)
a *= 2
print(a)
a //= 7
print(a)
a %= 7
print(a)
# Out:
# 110
# 220
# 31
# 3
