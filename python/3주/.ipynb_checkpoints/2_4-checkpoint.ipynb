# %% [markdown]
# 코드 2-27

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(f'{a} + {b} = {a+b}')
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} // {b} = {a//b}')
print(f'{a} % {b} = {a % b}')
print(f'{a} ** {b} = {a**b}')

# %% [markdown]
# 코드 2-28

# %%
ave = 70 + 80 + 90 / 3
print(ave)

# %% [markdown]
# 코드 2-29

# %%
ave = (70 + 80 + 90) / 3
print(ave)
